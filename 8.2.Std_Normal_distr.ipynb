# %%
import pandas as pd

# %%
dataset=pd.read_csv('preplacement.csv')

# %%
dataset.isna().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.distplot(dataset['ssc_p'])
# Out:
# C:\Users\mdfai\AppData\Local\Temp\ipykernel_8632\1572084834.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['ssc_p'])
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
def get_pdf_probability(dataset,startRange,endRange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'Yellow'},color='Green')
    pyplot.axvline(startRange,color='Red')
    pyplot.axvline(endRange,color='Red')
    #Generate sample
    sample=dataset
    #calculate parameters
    mean=sample.mean()
    std=sample.std()
    print("Mean=%.3f, Standard Deviation=%.3f" %(mean,std))
    #Define distribution
    dist=norm(mean,std)
    #sample probabilities for a range of outcomes
    values=[value for value in range(startRange,endRange)]
    prob=[dist.pdf(value) for value in values]
    probabilities=sum(prob)
    print("The area between range({},{}):{}".format(startRange,endRange,probabilities))
    return probabilities

# %%
#def get_pdf_probability(dataset,startRange,endRange):
    #from matplotlib import pyplot
    #from scipy.stats import norm
    #import seaborn as sns
    #ax=sns.distplot(dataset,kde=True,kde_kws={'color':'Yellow'},color='Green')
    #pyplot.axvline(startRange,color='Red')
    #pyplot.axvline(endRange,color='Red')
    #Generate sample
    #sample=dataset
    #calculate parameters
    #mean=sample.mean()
    #std=sample.std()
    #print("Mean=%.3f, Standard Deviation=%.3f" %(mean,std))
    #Define distribution
    #dist=norm(mean,std)
    #sample probabilities for a range of outcomes
    #values=[value for value in range(startRange,endRange)]
#values=[]
#for value in range(startRange,endRange)
#values.append(value)
    #prob=[dist.pdf(value) for value in values]
#prob=[]
#for value in values
#prob.append(dist.pdf(value)
    #probabilities=sum(prob)
    #print("The area between range({},{}):{}".format(startRange,endRange,probabilities))
    #return probabilities

# %%
get_pdf_probability(dataset['hsc_p'],60,70)
# Out:
# Mean=66.333, Standard Deviation=10.898
# The area between range(60,70):0.34911643265441233
# C:\Users\mdfai\AppData\Local\Temp\ipykernel_8632\2257807222.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True,kde_kws={'color':'Yellow'},color='Green')
# 0.34911643265441233

# %% [markdown]
# #CDF

# %%
from statsmodels.distributions.empirical_distribution import ECDF

# %%
cdf=ECDF(dataset['hsc_p'])

# %%
cdf(71)
# Out:
# 0.6930232558139534

# %%
def stdNDgraph(dataset):
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()
    z_score=[((i-mean)/std) for i in dataset]
    sns.distplot(z_score,kde=True)

# %%
stdNDgraph(dataset['hsc_p'])
# Out:
# C:\Users\mdfai\AppData\Local\Temp\ipykernel_8632\3367979634.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)
